# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/linux-kernel-revlog2023/out.csv

# %%
import pandas as pd

df = pd.read_csv('/kaggle/input/linux-kernel-revlog2023/out.csv')
df
# Out:
#          Unnamed: 0  author_timestamp  commit_utc_offset_hours  \
# 0                 0        1678868421                        1
# 1                 1        1678868420                        1
# 2                 2        1678533146                        1
# 3                 3        1678527621                        1
# 4                 4        1678459656                       -6
# ...             ...               ...                      ...
# 2461885     2461885        1113690237                       -7
# 2461886     2461886        1113690236                       -7
# 2461887     2461887        1113690235                       -7
# 2461888     2461888        1113690234                       -7
# 2461889     2461889        1113690233                       -7
#
#                                       commit_hash          author_name  \
# 0        dc87fad6448fc574456516404469c0c2c48d642e      Javier Carrasco
# ...

# %%
authr_email = "akpm@osdl.org"
def gen_graph(author_emai, ):
    authrdf = df[df.author_email.notnull()][df.author_email.dropna().str.contains("neilb@cse.unsw.edu.au")]
    t = pd.Series(time_df['diff'].values, index=time_df['author_dt'])
    t.plot(title=f'lines of code added by {author_email}', figsize=(12,8))

# %%
authrdf = df[df.author_email.notnull()][df.author_email.dropna().str.contains("tglx@linutronix.de")]
authrdf
# Out:
#          Unnamed: 0  author_timestamp  commit_utc_offset_hours  \
# 105             105        1677704868                        1
# 106             106        1677704868                        1
# 107             107        1677704868                        1
# 3670           3670        1675981549                        1
# 6538           6538        1675779413                        1
# ...             ...               ...                      ...
# 2458019     2458019        1107951600                        0
# 2458059     2458059        1107210144                        0
# 2458060     2458060        1107210078                        0
# 2458061     2458061        1107203806                        0
# 2458079     2458079        1106064900                        0
#
#                                       commit_hash      author_name  \
# 105      0fb7fb713461e44b12e72c292bf90ee300f40710  Thomas Gleixner
# 106      0fb7fb713461e44b12e72c292bf90ee300f40710  Thomas Gleixner
# ...

# %%
df3 = authrdf[['commit_utc_offset_hours', 'author_dt']]
df3.plot()
# Out:
# <AxesSubplot:>

# %%
    df[(df['author_timestamp'] > 1104600000) & (df['author_timestamp'] < 1487807212)]
    df['author_dt'] = pd.to_datetime(df['author_timestamp'],unit='s')
    df.head()
# Out:
#    Unnamed: 0  author_timestamp  commit_utc_offset_hours  \
# 0           0        1678868421                        1
# 1           1        1678868420                        1
# 2           2        1678533146                        1
# 3           3        1678527621                        1
# 4           4        1678459656                       -6
#
#                                 commit_hash          author_name  \
# 0  dc87fad6448fc574456516404469c0c2c48d642e      Javier Carrasco
# 1  b48cc753c017d1f5c6e317538205d40e70d04f3c      Javier Carrasco
# 2  cca1e2f790703bb22b56d94c5efc66c1d9517b21  Krzysztof Kozlowski
# 3  f69c2b5420497b7a54181ce170d682cbeb1f119f  Krzysztof Kozlowski
# 4  4d9890ac9d43d4dfd011110ab96633caa6fa829c          Rob Herring
#
#                      author_email  \
# 0  javier.carrasco@wolfvision.net
# 1  javier.carrasco@wolfvision.net
# 2  krzysztof.kozlowski@linaro.org
# 3  krzysztof.kozlowski@linaro.org
# 4                 robh@kernel.org
#
# ...

# %%
df_new = authrdf.iloc[:, [2,4,10,11]]
df_new
# Out:
#          commit_utc_offset_hours      author_name           author_dt  weekday
# 105                            1  Thomas Gleixner 2023-03-01 21:07:48        2
# 106                            1  Thomas Gleixner 2023-03-01 21:07:48        2
# 107                            1  Thomas Gleixner 2023-03-01 21:07:48        2
# 3670                           1  Thomas Gleixner 2023-02-09 22:25:49        3
# 6538                           1  Thomas Gleixner 2023-02-07 14:16:53        1
# ...                          ...              ...                 ...      ...
# 2458019                        0  Thomas Gleixner 2005-02-09 12:20:00        2
# 2458059                        0  Thomas Gleixner 2005-01-31 22:22:24        0
# 2458060                        0  Thomas Gleixner 2005-01-31 22:21:18        0
# 2458061                        0  Thomas Gleixner 2005-01-31 20:36:46        0
# 2458079                        0  Thomas Gleixner 2005-01-18 16:15:00        1
#
# ...

# %%
df_new.drop('commit_hash',axis=1)
# Out:
#              author_name           author_dt  weekday
# 105      Thomas Gleixner 2023-03-01 21:07:48        2
# 106      Thomas Gleixner 2023-03-01 21:07:48        2
# 107      Thomas Gleixner 2023-03-01 21:07:48        2
# 3670     Thomas Gleixner 2023-02-09 22:25:49        3
# 6538     Thomas Gleixner 2023-02-07 14:16:53        1
# ...                  ...                 ...      ...
# 2458019  Thomas Gleixner 2005-02-09 12:20:00        2
# 2458059  Thomas Gleixner 2005-01-31 22:22:24        0
# 2458060  Thomas Gleixner 2005-01-31 22:21:18        0
# 2458061  Thomas Gleixner 2005-01-31 20:36:46        0
# 2458079  Thomas Gleixner 2005-01-18 16:15:00        1
#
# [36271 rows x 3 columns]

# %%
df_new
# Out:
#          commit_utc_offset_hours      author_name           author_dt  weekday
# 105                            1  Thomas Gleixner 2023-03-01 21:07:48        2
# 106                            1  Thomas Gleixner 2023-03-01 21:07:48        2
# 107                            1  Thomas Gleixner 2023-03-01 21:07:48        2
# 3670                           1  Thomas Gleixner 2023-02-09 22:25:49        3
# 6538                           1  Thomas Gleixner 2023-02-07 14:16:53        1
# ...                          ...              ...                 ...      ...
# 2458019                        0  Thomas Gleixner 2005-02-09 12:20:00        2
# 2458059                        0  Thomas Gleixner 2005-01-31 22:22:24        0
# 2458060                        0  Thomas Gleixner 2005-01-31 22:21:18        0
# 2458061                        0  Thomas Gleixner 2005-01-31 20:36:46        0
# 2458079                        0  Thomas Gleixner 2005-01-18 16:15:00        1
#
# ...

# %%
df_new['weekday'] = df_max_scaled['weekday'] /df_max_scaled['weekday'].abs().max()
df_new
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          commit_utc_offset_hours      author_name           author_dt  \
# 105                            1  Thomas Gleixner 2023-03-01 21:07:48
# 106                            1  Thomas Gleixner 2023-03-01 21:07:48
# 107                            1  Thomas Gleixner 2023-03-01 21:07:48
# 3670                           1  Thomas Gleixner 2023-02-09 22:25:49
# 6538                           1  Thomas Gleixner 2023-02-07 14:16:53
# ...                          ...              ...                 ...
# 2458019                        0  Thomas Gleixner 2005-02-09 12:20:00
# ...

# %%
df_new['month'] = df_new['author_dt'].dt.month
df_new.groupby("month")
df_new
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          commit_utc_offset_hours      author_name           author_dt  \
# 105                            1  Thomas Gleixner 2023-03-01 21:07:48
# 106                            1  Thomas Gleixner 2023-03-01 21:07:48
# 107                            1  Thomas Gleixner 2023-03-01 21:07:48
# 3670                           1  Thomas Gleixner 2023-02-09 22:25:49
# 6538                           1  Thomas Gleixner 2023-02-07 14:16:53
# ...                          ...              ...                 ...
# 2458019                        0  Thomas Gleixner 2005-02-09 12:20:00
# ...

# %%
plt.scatter(df_new["commit_utc_offset_hours"], df_new['weekday'])

# %%
df["commit_utc_offset_hours"]
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4         -6
#           ..
# 2461885   -7
# 2461886   -7
# 2461887   -7
# 2461888   -7
# 2461889   -7
# Name: commit_utc_offset_hours, Length: 2461890, dtype: int64

# %%
df_new['commit_utc_offset_hours'].shape
# Out:
# (36271,)

# %%
df_new['weekday'].shape
# Out:
# (36271,)

# %%
df_final = pd.concat([df_new['weekday'],df_new['commit_utc_offset_hours']])

# %%
df_new['weekday']
# Out:
# 105        0.333333
# 106        0.333333
# 107        0.333333
# 3670       0.500000
# 6538       0.166667
#              ...
# 2458019    0.333333
# 2458059    0.000000
# 2458060    0.000000
# 2458061    0.000000
# 2458079    0.166667
# Name: weekday, Length: 36271, dtype: float64

# %%
df_new['commit_utc_offset_hours']
# Out:
# 105        1
# 106        1
# 107        1
# 3670       1
# 6538       1
#           ..
# 2458019    0
# 2458059    0
# 2458060    0
# 2458061    0
# 2458079    0
# Name: commit_utc_offset_hours, Length: 36271, dtype: int64

# %%
df_final
# Out:
# 105        0.333333
# 106        0.333333
# 107        0.333333
# 3670       0.500000
# 6538       0.166667
#              ...
# 2458019    0.000000
# 2458059    0.000000
# 2458060    0.000000
# 2458061    0.000000
# 2458079    0.000000
# Length: 72542, dtype: float64

# %%
X = df_final.to_numpy()
X = X.reshape(-1,1)

# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

centers = [[1, 1], [-1, -1], [1, -1]]

X = StandardScaler().fit_transform(X)

# %%
X
# Out:
# array([[-0.0083304 ],
#        [-0.0083304 ],
#        [-0.0083304 ],
#        ...,
#        [-0.15710035],
#        [-0.15710035],
#        [-0.15710035]])

# %%
X.shape
# Out:
# (72542, 1)

# %%
df_new['month'] = df_new['month'] /df_new['month'].abs().max()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_temp = df_new.loc[(df['month'] >= 6) & (df['weekday'] <= 0.25)]

# %%
df_temp.plot()
# Out:
# <AxesSubplot:>

# %%
df_newjoind = df_new[['weekday', 'month']].to_numpy().ravel().tolist()
df_newjoind
# Out:
# [0.3333333333333333,
#  3.0,
#  0.3333333333333333,
#  3.0,
#  0.3333333333333333,
#  3.0,
#  0.5,
#  2.0,
#  0.16666666666666666,
#  2.0,
#  0.16666666666666666,
#  2.0,
#  0.0,
#  1.0,
#  0.0,
#  1.0,
#  0.0,
#  1.0,
#  0.16666666666666666,
#  1.0,
#  0.0,
#  1.0,
#  0.0,
#  1.0,
#  0.6666666666666666,
#  12.0,
#  1.0,
#  11.0,
#  0.0,
#  11.0,
#  0.0,
#  11.0,
#  0.0,
#  11.0,
#  0.0,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
#  0.5,
#  11.0,
# ...

# %%
y = df_new['weekday']
x =  df_new['author_dt']
plt.scatter(x,y)

# %%
df_max_scaled = df_new.copy()

df_new['weekday'] = df_max_scaled['weekday'] /df_max_scaled['weekday'].abs().max()
df_new
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          commit_utc_offset_hours      author_name           author_dt  \
# 105                     0.333333  Thomas Gleixner 2023-03-01 21:07:48
# 106                     0.333333  Thomas Gleixner 2023-03-01 21:07:48
# 107                     0.333333  Thomas Gleixner 2023-03-01 21:07:48
# 3670                    0.500000  Thomas Gleixner 2023-02-09 22:25:49
# 6538                    0.166667  Thomas Gleixner 2023-02-07 14:16:53
# ...                          ...              ...                 ...
# ...

# %%
y = df_new['commit_utc_offset_hours']
x =  df_new['weekday']
plt.scatter(x,y)

# %%
y = df_new['commit_utc_offset_hours']
x =  df_new['author_dt']
plt.scatter(x,y)
